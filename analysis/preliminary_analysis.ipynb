# %% [markdown]
# # Preliminary analysis #
#
#
# ## loading default libraries for data-analysis ##

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Loading the data and check if data exists ##

# %%
titanic_data = pd.read_csv('../data/train.csv')

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Data quality assessment ##

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# Data values and types do seem reasonable, further checking for object type values is required

# %%
titanic_data.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# No surprises on these values

# %%
titanic_data.Ticket.unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %% [markdown]
# This needs further analysis if there is any usable data

# %%
titanic_data.Name.unique()
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Williams, Mr. Charles Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Masselmani, Mrs. Fatima', 'Fynney, Mr. Joseph J',
#        'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"',
# ...

# %% [markdown]
# Name -> nationality might provide some information, to be checked if results without it are not satisfactory

# %%
titanic_data.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %% [markdown]
# Here should be some usefull information, multiple nan values, different start letter, multiple cabins.

# %%
titanic_data.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# Port of embarcation should not matter but still it is good practice to check if there is any correlation. "nan" value might be of interest here.

# %%
sns.pairplot(titanic_data,hue="Survived",vars=["Pclass","Age","SibSp","Fare"])
# Out:
# /home/tuokall/anaconda3/envs/KaggleTitanic/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:444: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # will not work for two columns.
# /home/tuokall/anaconda3/envs/KaggleTitanic/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:444: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # will not work for two columns.
# /home/tuokall/anaconda3/envs/KaggleTitanic/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:444: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # will not work for two columns.
# /home/tuokall/anaconda3/envs/KaggleTitanic/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:444: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # will not work for two columns.

# %% [markdown]
# no surprises: lower class / cheaper ticket -> lower surviability, small children higher surviability, few siblings higher surviability.

# %%
sns.pairplot(titanic_data[titanic_data.Survived == 0], vars=["Parch","Age"])
# Out:
# /home/tuokall/anaconda3/envs/KaggleTitanic/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/tuokall/anaconda3/envs/KaggleTitanic/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.pairplot(titanic_data[titanic_data.Survived == 1], vars=["Parch","Age"])

# %%
sns.catplot(x="Sex",y="Survived",data=titanic_data, hue="Embarked", kind="bar")

# %% [markdown]
# Sex and embarkation point both have effect on survivability

# %%
titanic_data.Embarked.value_counts(dropna=False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %%
titanic_data.Cabin.value_counts(dropna=False)
# Out:
# NaN            687
# B96 B98          4
# C23 C25 C27      4
# G6               4
# C22 C26          3
#               ...
# C103             1
# A32              1
# C47              1
# F E69            1
# D37              1
# Name: Cabin, Length: 148, dtype: int64

# %% [markdown]
# -> NaN significant information. Cabin letter + multiple cabins most likely relevant, cabin number irrelevant

# %% [markdown]
# # Results
#
# ## Variables in data
#
# - **PassengerId** Unique identifier, no relationship to Survivability
# - **Survived** Information on survival, *0=No, 1=Yes*
# - **Pclass** Ticket class, *1=1st class, 2=2nd class, 3=3rd class*, **extremely** relevant
# - **Name** Passenger name, on 1st approximation *ir*relevant, could be used for nationality determination which might be relevant
# - **Sex** Passenger Sex, **extremely** relevant
# - **Age** Passenger Age in years, relevant, null-value handling to be determined
# - **SibSp** number of siblings / spouses aboard the Titanic, relevant
# - **Parch** number of parents / children aboard, relevant, should most likely be transformed to two different variables based on age
# - **Ticket** Ticket number, **most likely** irrelevant to be analyzed if model doesn't perform properly without it
# - **Fare** Passenger fare, relevant
# - **Cabin** Cabin number. ***Many empty values -> these are highly relevant***, **Letter value** might be relevant -> to be analysed, **multiple cabins** might be relevant -> to be analysed.
# - **Embarked** Port of Embarkation, seems to be relevant.
#
# ## Further analysis & used techniques
#
# Cabin number analysis for transforming it usefull data.
#
# ### Prediction engines to be used
#
# - Decision Tree
# - Spectral Clustering
# - Neural Network
